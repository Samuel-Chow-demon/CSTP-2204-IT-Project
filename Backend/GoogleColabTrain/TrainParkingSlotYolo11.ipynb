# %%
# !nvidia-smi
# Out:
# Fri Jan 17 23:44:56 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # New Section

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.6/911.6 kB 8.8 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="39l6U5ozmkIL1IfOfU8Z")
project = rf.workspace("cstp-2204").project("parking-space-detector-pjznj")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to parking-space-detector-1 in yolov11:: 100%|██████████| 1954/1954 [00:01<00:00, 1832.82it/s]

# %%
# !yolo detect train data=/content/parking-space-finder-1/data.yaml model=yolo11l.pt epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !rm -r /content/parking-space-detector/

# %%
# !rm -rf /content/*

# %%
# !ls parking-space-finder-1/
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
import shutil
from google.colab import files

shutil.make_archive("parking-space-finder-1", 'zip', "/content/parking-space-finder-1")
shutil.make_archive("runs", 'zip', "runs")

files.download('runs.zip')
files.download('parking-space-finder-1.zip')
